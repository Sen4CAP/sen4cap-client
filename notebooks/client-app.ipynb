# %% [markdown]
# # Client GUI Usage
#
# The following section shows how to use the Sen4CAP client's GUI usin
#
# - `client.show_app()`: to open the GUI of the app,
# - `client.app_store`: to interact with the app's data,
#
#
# **Important:** Make sure you have already configured the client to run with the TAO Process API server. In a command shell run `sen4cap-client configure` and enter your credentials given that they differ from the provided default values.
#
# ---

# %%
import json

from sen4cap_client.api import create_client

# %% [markdown]
# ## Create the client

# %% [markdown]
# Get credentials allowing us to use the Sen4CAP processing system.

# %%
with open("credentials.json") as f:
    credentials = json.load(f)

# %% [markdown]
# Create a Sen4CAP client instance with your user credentials.

# %%
client = create_client(**credentials)

# %% [markdown]
# ## Show the app

# %%
client.show_app(height=500)
# Out:
#             <div class="eozilla-frame-root"></div>
#             <script>
#             (() => {
#               function detectJupyterScheme() {
#                 const body = document.body;
#                 const root = document.documentElement;
#
#                 const themeLight =
#                   body.getAttribute("data-jp-theme-light") ??
#                   root.getAttribute("data-jp-theme-light");
#
#                 if (themeLight === "true") return "light";
#                 if (themeLight === "false") return "dark";
#
#                 const bg =
#                   getComputedStyle(root).getPropertyValue("--jp-layout-color0") ||
#                   getComputedStyle(body).backgroundColor;
#
#                 const match = bg.match(/\d+/g);
#                 if (match && match.length >= 3) {
#                   const [r, g, b] = match.slice(0, 3).map(Number);
#                   const luminance = (0.2126 * r + 0.7152 * g + 0.0722 * b) / 255;
#                   return luminance < 0.5 ? "dark" : "light";
#                 }
#
#                 return null;
#               }
#
#               const root = document.currentScript.previousElementSibling;
#               const scheme = detectJupyterScheme();
#               const src = new URL("http://127.0.0.1:60217/index.html?compact=1&_t=1782483173&service=...&ws=ws%3A%2F%2F127.0.0.1%3A60217%2Fws", window.location.href);
#
#               if (scheme) {
#                 src.searchParams.set("scheme", scheme);
#               }
#
#               const iframe = document.createElement("iframe");
#               iframe.src = src.toString();
#               iframe.width = "100%";
#               iframe.height = "500px";
#               iframe.style.border = "0";
#               iframe.style.width = "100%";
#               iframe.style.height = "500px";
#               iframe.allow = "clipboard-read; clipboard-write";
#
#               root.replaceChildren(iframe);
#             })();
#             </script>
# WebSocket message decoding failed: 1 validation error for tagged-union[GetMessage,SetMessage,ActionMessage,QueryMessage]
# set.value
#   Field required [type=missing, input_value={'type': 'set', 'call_id'...8dc-ac9a-6470d2c39eb8']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/missing
# Traceback (most recent call last):
#   File "C:\Users\norma\Projects\sen4cap-client\.pixi\envs\default\Lib\site-packages\remotestate\server.py", line 236, in _handle_ws
#     msg = _IncomingAdapter.validate_json(msg_text, by_alias=True)
#   File "C:\Users\norma\Projects\sen4cap-client\.pixi\envs\default\Lib\site-packages\pydantic\type_adapter.py", line 492, in validate_json
#     return self.validator.validate_json(
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
#         data,
#         ^^^^^
#     ...<5 lines>...
#         by_name=by_name,
#         ^^^^^^^^^^^^^^^^
#     )
#     ^
# pydantic_core._pydantic_core.ValidationError: 1 validation error for tagged-union[GetMessage,SetMessage,ActionMessage,QueryMessage]
# set.value
#   Field required [type=missing, input_value={'type': 'set', 'call_id'...8dc-ac9a-6470d2c39eb8']}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.13/v/missing

# %%
client.app_store["processRequests"]["218"]["inputs"]["c30145a7-029c-4499-98bc-9903ca46531c"] = "2026-06-01"

# %%
client.app_store["processRequests"]["218"]["inputs"]["472efeab-514a-4e15-9dba-d5812d653065"] = "2026-06-01"

# %%
client.app_store["processRequests"]["218"]
# Out:
# {'inputs': {'c30145a7-029c-4499-98bc-9903ca46531c': '2025-08-01',
#   '472efeab-514a-4e15-9dba-d5812d653065': '2026-06-01',
#   '691adc8e-9bba-4f42-86e2-ccd72189edc3': 'NDVI',
#   'bed1920e-51c0-406e-b22e-70d1f86d95d4': 'POLYGON ((10.113209148212974 53.563533046304514,10.322239055986046 53.563533046304514,10.322239055986046 53.448835335626626,10.113209148212974 53.448835335626626,10.113209148212974 53.563533046304514))'},
#  'outputs': {'db96d3e8-0243-48dc-ac9a-6470d2c39eb8': {}}}
